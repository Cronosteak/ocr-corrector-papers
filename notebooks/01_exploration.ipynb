# %% [markdown]
# # 01 — Exploración del Dataset
#
# EDA del dataset de pares OCR ↔ ground truth:
# - Distribución de errores OCR (CER/WER)
# - Longitud de textos
# - Tipos de errores más comunes

# %%
import json
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar dataset
with open('../data/pairs/dataset.json', 'r') as f:
    pairs = json.load(f)

print(f'Total de pares: {len(pairs)}')
