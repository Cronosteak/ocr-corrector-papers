# %% [markdown]
# # 03 — Resultados del Modelo
#
# Análisis de métricas CER/WER antes y después de la corrección:
# - Comparación baseline vs modelo
# - Ejemplos de correcciones
# - Análisis de errores residuales

# %%
from src.model.evaluate import evaluate_model

# Evaluar baseline (sin modelo)
results = evaluate_model()
print(f'Baseline CER: {results["baseline_cer"]:.4f}')
print(f'Baseline WER: {results["baseline_wer"]:.4f}')
